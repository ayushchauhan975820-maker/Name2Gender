# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/danielveazey/genderbyname/master/names_genders.csv')
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#       Name Gender    Count  Probability
# 0    James      M  5304407     0.014517
# 1     John      M  5260831     0.014398
# 2   Robert      M  4970386     0.013603
# 3  Michael      M  4579950     0.012534
# 4  William      M  4226608     0.011567

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147269 entries, 0 to 147268
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Name         147269 non-null  object
#  1   Gender       147269 non-null  object
#  2   Count        147269 non-null  int64
#  3   Probability  147269 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# Name           0
# Gender         0
# Count          0
# Probability    0
# dtype: int64

# %%
df["name_lower"] = df["Name"].astype(str).str.lower()
df["last_letter"] = df["name_lower"].str[-1]
df["first_letter"] = df["name_lower"].str[0]
df["length"] = df["name_lower"].apply(len)
df["vowel_count"] = df["name_lower"].apply(lambda x : sum(1 for c in x if c in 'aeiou'))

# %%
df.head()
# Out:
#       Name  Gender name_lower last_letter first_letter  length  vowel_count
# 0  AALIYAH       0    aaliyah           h            a       7            4
# 1   AARIKA       0     aarika           a            a       6            4
# 2    AARON       0      aaron           n            a       5            3
# 3    AARON       1      aaron           n            a       5            3
# 4       AB       0         ab           b            a       2            1

# %%
df.isnull().sum()
# Out:
# Name            0
# Gender          0
# name_lower      0
# last_letter     0
# first_letter    0
# length          0
# vowel_count     0
# dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bins = range(2, 15)

ax1.hist(df[df['Gender'] == 1]['length'], bins=bins, alpha=0.6, color='blue', label='Male (1)', density=True, align='left')
ax1.hist(df[df['Gender'] == 0]['length'], bins=bins, alpha=0.6, color='orange', label='Female (0)', density=True, align='left')
ax1.set_title('Distribution of Name Lengths')
ax1.set_xlabel('Length of Name')
ax1.set_ylabel('Proportion')
ax1.set_xticks(bins[:-1])
ax1.legend()
ax1.grid(axis='y', alpha=0.3)

alphabet = 'abcdefghijklmnopqrstuvwxyz'

male_letter_counts = df[df['Gender'] == 1]['last_letter'].value_counts()
female_letter_counts = df[df['Gender'] == 0]['last_letter'].value_counts()

male_probs = [male_letter_counts.get(letter, 0) / len(df[df['Gender'] == 1]) for letter in alphabet]
female_probs = [female_letter_counts.get(letter, 0) / len(df[df['Gender'] == 0]) for letter in alphabet]

x = np.arange(len(alphabet))
width = 0.40

ax2.bar(x - width/2, male_probs, width, label='Male (1)', color='blue', alpha=0.6)
ax2.bar(x + width/2, female_probs, width, label='Female (0)', color='orange', alpha=0.6)

ax2.set_title('Distribution of Last Letters')
ax2.set_xlabel('Last Letter')
ax2.set_ylabel('Proportion')
ax2.set_xticks(x)
ax2.set_xticklabels(list(alphabet))
ax2.legend()
ax2.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
vowels = df.groupby(['length', 'Gender'])['vowel_count'].mean().unstack()

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(vowels.index, vowels[1], marker='o', color='blue', label='Male (1)', linewidth=2)
ax.plot(vowels.index, vowels[0], marker='o', color='orange', label='Female (0)', linewidth=2)

ax.set_title("avg vowel count per name length: Boys vs Girls")
ax.set_xlabel("Length of Name", fontsize=12)
ax.set_ylabel("Avg no of vowels", fontsize=12)
ax.set_xticks(vowels.index)
ax.legend(fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5) 

plt.tight_layout()
plt.show()
